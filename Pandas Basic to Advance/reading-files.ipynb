# %%
import pandas as pd
import numpy as np
import matplotlib.pyplotl as plt

# %matplotlib inline

# %%
file_string_name = (r'C:\Users\Bharathi Sindu\Desktop\data_analysis\Planet.csv')
planet = pd.read_csv(file_string_name)
planet
# Out:
#     Planet       Mass Diameter  DayLength  SunDistance OrbitPeriod  \
# 0  MERCURY     0.3300     4879     4222.6         57.9          88
# 1    VENUS     4.8700   12,104     2802.0        108.2       224.7
# 2    EARTH     5.9700   12,756       24.0        149.6       365.2
# 3     MOON     0.0730     3475      708.7          NaN        27.3
# 4     MARS     0.6420     6792       24.7        227.9         687
# 5  JUPITER  1898.0000  142,984        9.9        778.6        4331
# 6   SATURN   568.0000  120,536       10.7       1433.5      10,747
# 7   URANUS    86.8000   51,118       17.2       2872.5      30,589
# 8  NEPTUNE   102.0000   49,528       16.1       4495.1      59,800
# 9    PLUTO     0.0146     2370      153.3       5906.4      90,560
#
#    OrbitVelocity  MeanTemperature  SurfacePressure  Moons Rings MagneticField  \
# 0           47.4              167          0.00000      0    No           Yes
# ...

# %%
planet.index
# Out:
# Index(['MERCURY', 'VENUS', 'EARTH', 'MOON', 'MARS', 'JUPITER', 'SATURN',
#        'URANUS', 'NEPTUNE', 'PLUTO'],
#       dtype='object', name='Planet')

# %%
planet.set_index('Planet')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-38-5f68159326c5> in <module>
# ----> 1 planet.set_index('Planet')
#
# E:\Anaconda\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4394
#    4395         if missing:
# -> 4396             raise KeyError("None of {} are in the columns".format(missing))
#    4397
#    4398         if inplace:
#
# KeyError: "None of ['Planet'] are in the columns"

# %%
planet = pd.read_csv(file_string_name,usecols=[0,1,2,3])
planet
# Out:
#     Planet       Mass Diameter  DayLength
# 0  MERCURY     0.3300     4879     4222.6
# 1    VENUS     4.8700   12,104     2802.0
# 2    EARTH     5.9700   12,756       24.0
# 3     MOON     0.0730     3475      708.7
# 4     MARS     0.6420     6792       24.7
# 5  JUPITER  1898.0000  142,984        9.9
# 6   SATURN   568.0000  120,536       10.7
# 7   URANUS    86.8000   51,118       17.2
# 8  NEPTUNE   102.0000   49,528       16.1
# 9    PLUTO     0.0146     2370      153.3

# %%
planet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
# Planet       10 non-null object
# Mass         10 non-null float64
# Diameter     10 non-null object
# DayLength    10 non-null float64
# dtypes: float64(2), object(2)
# memory usage: 448.0+ bytes

# %%
planet.describe()
# Out:
#               Mass    DayLength
# count    10.000000    10.000000
# mean    266.669960   798.920000
# std     599.249294  1484.233185
# min       0.014600     9.900000
# 25%       0.408000    16.375000
# 50%       5.420000    24.350000
# 75%      98.200000   569.850000
# max    1898.000000  4222.600000

# %%
planet.set_index('Planet',inplace=True)

# %%
planet
# Out:
#               Mass Diameter  DayLength
# Planet
# MERCURY     0.3300     4879     4222.6
# VENUS       4.8700   12,104     2802.0
# EARTH       5.9700   12,756       24.0
# MOON        0.0730     3475      708.7
# MARS        0.6420     6792       24.7
# JUPITER  1898.0000  142,984        9.9
# SATURN    568.0000  120,536       10.7
# URANUS     86.8000   51,118       17.2
# NEPTUNE   102.0000   49,528       16.1
# PLUTO       0.0146     2370      153.3

# %%
planet = pd.read_csv(file_string_name)
planet
# Out:
#     Planet       Mass Diameter  DayLength  SunDistance OrbitPeriod  \
# 0  MERCURY     0.3300     4879     4222.6         57.9          88
# 1    VENUS     4.8700   12,104     2802.0        108.2       224.7
# 2    EARTH     5.9700   12,756       24.0        149.6       365.2
# 3     MOON     0.0730     3475      708.7          NaN        27.3
# 4     MARS     0.6420     6792       24.7        227.9         687
# 5  JUPITER  1898.0000  142,984        9.9        778.6        4331
# 6   SATURN   568.0000  120,536       10.7       1433.5      10,747
# 7   URANUS    86.8000   51,118       17.2       2872.5      30,589
# 8  NEPTUNE   102.0000   49,528       16.1       4495.1      59,800
# 9    PLUTO     0.0146     2370      153.3       5906.4      90,560
#
#    OrbitVelocity  MeanTemperature  SurfacePressure  Moons Rings MagneticField  \
# 0           47.4              167          0.00000      0    No           Yes
# ...

# %%
planet.set_index('Planet',inplace=True)

# %%
type(planet.FirstVisited['MERCURY'])
# Out:
# str

# %%
import datetime
pd.to_datetime(planet.FirstVisited)
# Out:
# Planet
# MERCURY   1974-03-29
# VENUS     1962-08-27
# EARTH            NaT
# MOON      1959-09-12
# MARS      1965-07-15
# JUPITER   1973-12-04
# SATURN    1979-09-01
# URANUS    1986-01-24
# NEPTUNE   1989-08-25
# PLUTO     2015-07-14
# Name: FirstVisited, dtype: datetime64[ns]

# %%
planet.FirstVisited = pd.to_datetime(planet.FirstVisited)

# %%
planet.FirstVisited.dt.year
# Out:
# Planet
# MERCURY    1974.0
# VENUS      1962.0
# EARTH         NaN
# MOON       1959.0
# MARS       1965.0
# JUPITER    1973.0
# SATURN     1979.0
# URANUS     1986.0
# NEPTUNE    1989.0
# PLUTO      2015.0
# Name: FirstVisited, dtype: float64

# %%
2050 - planet.FirstVisited.dt.year
# Out:
# Planet
# MERCURY    76.0
# VENUS      88.0
# EARTH       NaN
# MOON       91.0
# MARS       85.0
# JUPITER    77.0
# SATURN     71.0
# URANUS     64.0
# NEPTUNE    61.0
# PLUTO      35.0
# Name: FirstVisited, dtype: float64
